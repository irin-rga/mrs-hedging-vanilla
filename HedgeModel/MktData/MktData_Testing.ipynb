# %%
from datetime import datetime, date
from pathlib import Path
import pandas as pd
import os


from crossasset.crossasset_base import CrossAssetContext
from nxpy import pro
app = pro.Application()
warning = pro.ApplicationWarning()


from mkt_data import MktData

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def get_view(obj_id, headers):
    data = pro.ApplicationData()
    warning = pro.ApplicationWarning()
    app.view(obj_id, headers, data, warning)
    if warning.count_fatals() > 0:
        raise Exception(str(warning))
    return data

def get_view(obj_id):
    data = pro.ApplicationData()
    warning = pro.ApplicationWarning()
    app.view(obj_id, data, warning)
    if warning.count_fatals() > 0:
        raise Exception(str(warning))
    return data

# %%
# Read calendars and conventions
conventions_path = Path(Path(os.getcwd()), "USMktConventions.nxt")
print(conventions_path)
app.read_nxt(conventions_path, pro.ApplicationWarning())
# Out:
# \\rgare.net\stlfinmkts\MarketRiskMgmt\Pricing Requests\2024-Orion - IUL Hedging\RGA_Process\1_Code\HedgeModel\MktData\USMktConventions.nxt

# %%
app.get_all_ids()
# Out:
# ['GLOBALCALS.NEWYORK',
#  'GLOBALCALS.NEWYORK.DATA',
#  'GLOBALHELPINFO',
#  'GLOBALINDEXINFO',
#  'GLOBALINFO',
#  'GLOBALOBJECTS',
#  'GLOBALPARSEINFO',
#  'GLOBALWARNINGS',
#  'TIMEZONE.NEWYORK',
#  'TIMEZONE.NEWYORK.DATA']

# %%
# app.view('GlobalCals.NewYork', pro.ApplicationData(), pro.ApplicationWarning())
print(get_view('GlobalCals.NewYork'))
# Out:
# CODE    DATES       WEEKDAYS CALL HEADERS CALL VALUES             OUTPUT HEADERS OUTPUT VALUES        DEPENDENCIES
# NEWYORK 1-jan-2007  false    PREFIX       GlobalCals              UPDATED        7 @ 03:32:31 PM      GLOBALCALS.NEWYORK.DATA
#         6-jan-2007  true     NAME         NEWYORK                 ID             GLOBALCALS.NEWYORK
#         7-jan-2007  true     OBJECT       SETTINGS                LOCAL ID       GLOBALCALS.NEWYORK
#         13-jan-2007 true     TYPE         CALENDAR                TIMER          0.000966999970842153
#         14-jan-2007 true     CODE         NEWYORK                 TIMER CPU      0
#         15-jan-2007 true     SUNDAY       false
#         20-jan-2007 false    MONDAY       true
#         21-jan-2007          TUESDAY      true
#         27-jan-2007          WEDNESDAY    true
#         28-jan-2007          THURSDAY     true
#         3-feb-2007           FRIDAY       true
#         4-feb-2007           SATURDAY     false
# ...

# %%
# tickers = ['MXEA Index', 'RTY Index', 'NDX Index', 'SPX Index', 'SPMARC5P Index']
tickers = ['MXEA Index', 'RTY Index', 'SPX Index']
mktdata = MktData(tickers)

# %%
# test_val_dt = date(2023, 1, 20)
test_val_dt = date(2024, 10, 1)
test_val_dt
# Out:
# datetime.date(2024, 10, 1)

# %%
mktdata.load_implied_vol(test_val_dt)
# Out:
# Reading Excel Data for MXEA on 2024-10-01
# Building Yield Curve for MXEA on 2024-10-01
# Building Dividend Curve for MXEA on 2024-10-01
# Building Vol Surface for MXEA on 2024-10-01
# Reading Excel Data for RTY on 2024-10-01
# Building Yield Curve for RTY on 2024-10-01
# Building Dividend Curve for RTY on 2024-10-01
# Building Vol Surface for RTY on 2024-10-01
# Reading Excel Data for SPX on 2024-10-01
# Building Yield Curve for SPX on 2024-10-01
# Building Dividend Curve for SPX on 2024-10-01
# Building Vol Surface for SPX on 2024-10-01

# %%
mktdata.get_px(test_val_dt, 'SPX Index')
# Out:
# 5708.75

# %%
spx_vol = mktdata.get_vol(test_val_dt, 'SPX Index')
spx_vol

# %%
mktdata.app.get_all_ids()
# Out:
# ['GLOBALCALS.NEWYORK',
#  'GLOBALCALS.NEWYORK.DATA',
#  'GLOBALHELPINFO',
#  'GLOBALINDEXINFO',
#  'GLOBALINFO',
#  'GLOBALOBJECTS',
#  'GLOBALPARSEINFO',
#  'GLOBALWARNINGS',
#  'MXEA_DIV',
#  'MXEA_DIVDATA',
#  'MXEA_IVSURF',
#  'MXEA_IV_MATRIX',
#  'MXEA_YC',
#  'MXEA_YCDATA',
#  'RTY_DIV',
#  'RTY_DIVDATA',
#  'RTY_IVSURF',
#  'RTY_IV_MATRIX',
#  'RTY_YC',
#  'RTY_YCDATA',
#  'SPX_DIV',
#  'SPX_DIVDATA',
#  'SPX_IVSURF',
#  'SPX_IV_MATRIX',
#  'SPX_YC',
#  'SPX_YCDATA',
#  'TIMEZONE.NEWYORK',
#  'TIMEZONE.NEWYORK.DATA']

# %%
test_matrix = pro.ApplicationMatrix()
warning = pro.ApplicationWarning()
mktdata.app.view_as_matrix('SPX_IV_MATRIX', test_matrix, warning)
print(test_matrix)
# Out:
#             0.5      0.6      0.7      0.8      0.9      0.95     1        1.05     1.1      1.2      1.3      1.4      1.5
# 18-oct-2024 0.953103 0.787468 0.646137 0.473625 0.292159 0.217288 0.148067 0.122752 0.158574 0.244186 0.318221 0.381887 0.43893
# 15-nov-2024 0.701133 0.591494 0.475368 0.359608 0.257581 0.213465 0.166292 0.12827  0.124887 0.165824 0.209237 0.247403 0.281726
# 20-dec-2024 0.609615 0.506926 0.408643 0.315539 0.23672  0.20011  0.161411 0.128793 0.117472 0.142312 0.178586 0.210842 0.239317
# 21-mar-2025 0.486975 0.407423 0.336336 0.273843 0.217115 0.188867 0.160581 0.135758 0.119679 0.117567 0.138173 0.160195 0.180106
# 20-jun-2025 0.426447 0.360265 0.30261  0.253617 0.210379 0.18789  0.164622 0.14253  0.125441 0.112472 0.121867 0.137258 0.152337
# 19-sep-2025 0.389208 0.332337 0.284947 0.244739 0.208406 0.189643 0.169678 0.149902 0.132524 0.114245 0.11571  0.12614  0.138012
# ...

# %%
test_data = pro.ApplicationData()
mktdata.app.view('SPX_IVSURF', test_data, warning)
print(test_data)
# Out:
# DATES       1986.305 2383.566 2780.827 3178.088 3575.349 3773.9795 3972.61  4171.2405 4369.871 4767.132 5164.393 5561.654 5958.915 STRIKES   DEFAULTED HEADINGS        DEFAULTED VALUES CALL HEADERS                 CALL VALUES   OUTPUT HEADERS OUTPUT VALUES        DEPENDENCIES  QUOTES
# 17-feb-2023 0.648244 0.548469 0.465786 0.358972 0.251489 0.215938  0.183699 0.158184  0.157734 0.197555 0.239649 0.27766  0.312121 1986.305  TIMEEXTRAPOLATIONMETHOD   FLAT             NOWDATE                      20-jan-2023   UPDATED        27 @ 07:20:09 PM     SPX_DIV       #SPX_IVSURF.SPOTPRICE
# 17-mar-2023 0.571779 0.498191 0.40829  0.313934 0.241563 0.213579  0.184265 0.159267  0.14797  0.168863 0.197557 0.225648 0.251831 2383.566  TIMEEXTRAPOLATIONVARIABLE SIGMA1           CURRENCY                     USD           ID             SPX_IVSURF           SPX_IV_MATRIX
# ...

# %%
spx_vol = mktdata.get_vol(test_val_dt, 'SPX Index')

# %%
# add_tenor(self: nxpy.pro.Application, date: NumeriX::Date, tenor: str, conventions: str, calendar: str, warning: PyApplicationWarning, end_of_month: bool) → NumeriX::Date
# 'GLOBALCALS.NEWYORK'
test_dt = test_val_dt
# test_dt = date(2026, 1, 2)
test_expiry = mktdata.app.add_tenor(test_dt, '1Y', 'P', 'NewYork', warning, False)
test_expiry
# Out:
# datetime.date(2025, 10, 1)

# %%
# get_implied_volatility(self: nxpy.pro.Application, vol_surface_id: str, date: NumeriX::Date, strike: float, w: PyApplicationWarning)
k_low = 5708.75
k_high = 6236.81
iv_low = mktdata.app.get_implied_volatility(spx_vol.vol_surf.get_id(), test_expiry, k_low, warning)
iv_high = mktdata.app.get_implied_volatility(spx_vol.vol_surf.get_id(), test_expiry, k_high, warning)
iv_low, iv_high
# Out:
# (0.17021492003962266, 0.13628485430577458)

# %%
mktdata.app.get_day_count_fraction('Act/365.25', test_dt, test_expiry, warning)
# Out:
# 0.999315537303217

# %%
test_idx = 'SPX Index'
test_dt = date(2024, 10, 1)
# test_expiry = mktdata.app.add_tenor(test_dt, '1Y', 'P', 'NewYork', warning, False)
test_expiry = mktdata.get_maturity(test_dt, 1)
k_low = 5708.75
k_high = 6236.81
mktdata.get_iv(test_val_dt, test_idx, test_expiry, k_low), mktdata.get_iv(test_val_dt, test_idx, test_expiry, k_high)
# Out:
# (0.17021492003962266, 0.13628485430577458)

# %%
q = mktdata.get_q(test_dt, test_idx, test_expiry)
rfr = mktdata.get_rfr(test_dt, test_idx, test_expiry)
ttm = mktdata.get_ttm(test_dt, test_expiry)
df = mktdata.get_df(test_dt, test_idx, test_expiry)
q, rfr, ttm, df
# Out:
# (0.005535188065538897,
#  0.03821102649342675,
#  0.999315537303217,
#  0.9625349782214802)

# %%
# px_df.set_index('AsOfDate', inplace=True)

# %%
px_df
# Out:
#             MXEA Index  RTY Index  NDX Index  SPX Index  SPMARC5P Index
# AsOfDate
# 2022-12-30     1943.93   1761.246   10939.76    3839.50          352.48
# 2023-01-02     1955.87        NaN        NaN        NaN             NaN
# 2023-01-03     1960.08   1750.734   10862.64    3824.14          353.13
# 2023-01-04     1981.40   1772.544   10914.80    3852.97          354.17
# 2023-01-05     1961.42   1753.193   10741.22    3808.10          353.16
# ...                ...        ...        ...        ...             ...
# 2024-11-27     2294.57   2426.192   20744.49    5998.74          386.06
# 2024-11-28     2302.19        NaN        NaN        NaN             NaN
# 2024-11-29     2315.77   2434.726   20930.37    6032.38          387.45
# 2024-12-02     2319.85   2434.139   21164.60    6047.15          386.98
# 2024-12-03         NaN   2415.197   21150.04    6037.71             NaN
#
# [503 rows x 5 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\S0053071\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'AsOfDate'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ...

# %%
px_dict = px_df.set_index('AsOfDate').to_dict('index')
px_dict
# Out:
# {datetime.date(2022, 12, 30): {'MXEA Index': 1943.93,
#   'RTY Index': 1761.246,
#   'NDX Index': 10939.76,
#   'SPX Index': 3839.5,
#   'SPMARC5P Index': 352.48},
#  datetime.date(2023, 1, 2): {'MXEA Index': 1955.87,
#   'RTY Index': nan,
#   'NDX Index': nan,
#   'SPX Index': nan,
#   'SPMARC5P Index': nan},
#  datetime.date(2023, 1, 3): {'MXEA Index': 1960.08,
#   'RTY Index': 1750.734,
#   'NDX Index': 10862.64,
#   'SPX Index': 3824.14,
#   'SPMARC5P Index': 353.13},
#  datetime.date(2023, 1, 4): {'MXEA Index': 1981.4,
#   'RTY Index': 1772.544,
#   'NDX Index': 10914.8,
#   'SPX Index': 3852.97,
#   'SPMARC5P Index': 354.17},
#  datetime.date(2023, 1, 5): {'MXEA Index': 1961.42,
#   'RTY Index': 1753.193,
#   'NDX Index': 10741.22,
#   'SPX Index': 3808.1,
#   'SPMARC5P Index': 353.16},
#  datetime.date(2023, 1, 6): {'MXEA Index': 1995.78,
#   'RTY Index': 1792.8,
#   'NDX Index': 11040.35,
#   'SPX Index': 3895.08,
#   'SPMARC5P Index': 355.71},
# ...

# %%
type(list(px_dict.keys())[0])
# Out:
# datetime.date

# %%
from equity_prices import EquityPrices

# %%
prices = EquityPrices()

# %%
test_dt = date(2022,12,30)
idx = 'SPMARC5P Index'
test_px = prices.get_px(test_dt, idx)
print(f'Price for {idx} on {test_dt} was {test_px}')
# Out:
# Price for SPMARC5P Index on 2022-12-30 was 352.48

# %%
test_dt = date(2024,11,27)
idx = 'MXEA Index'
test_px = prices.get_px(test_dt, idx)
print(f'Price for {idx} on {test_dt} was {test_px}')
# Out:
# Price for MXEA Index on 2024-11-27 was 2294.57

# %%
test_dt = date(2024,11,28)
idx = 'SPMARC5P Index'
test_px = prices.get_px(test_dt, idx)
print(f'Price for {idx} on {test_dt} was {test_px}')
# Out:
# Price for SPMARC5P Index on 2024-11-28 was nan

# %%
print(prices.px_dict.get(test_dt, None))
# Out:
# {'MXEA Index': 2302.19, 'RTY Index': nan, 'NDX Index': nan, 'SPX Index': nan, 'SPMARC5P Index': nan}

# %%
type(prices.px_dict[test_dt][idx])
# Out:
# float

# %%
import math
math.isnan(prices.px_dict[test_dt][idx])
# Out:
# True
